# %% [markdown]
# **1. Import the packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\ajcho\OneDrive\Desktop\full stack data science and AI\Data Files\Salary_Data - Salary_Data.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %% [markdown]
# **3. Data Quick checks**
#
# - Shape - [shape]
# - Size - [size]
# - Length - [len]
# - Data type - [dtypes]
# - columns

# %%
#shape
print(f'Shape of Dataset:{df.shape}')
print('----------------------------')
#size 
print(f'Size of dataset:{df.size}')
print('----------------------------')
#length
print(f'Length of Dataset:{len(df)}')
print('----------------------------')
#dtypes
print(df.dtypes)
print('----------------------------')
#columns
print(df.columns)
# Out:
# Shape of Dataset:(30, 2)
# ----------------------------
# Size of dataset:60
# ----------------------------
# Length of Dataset:30
# ----------------------------
# YearsExperience    float64
# Salary               int64
# dtype: object
# ----------------------------
# Index(['YearsExperience', 'Salary'], dtype='object')

# %% [markdown]
# **4. Divide the Data into X and y**

# %%
X=df.drop('Salary',axis=1)
y=df['Salary']

# %% [markdown]
# - Quick cheak the data

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# Name: Salary, dtype: int64

# %% [markdown]
# **5. Split the data into train and test**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1234,test_size=0.30)

# %% [markdown]
# - Quick data cheak

# %%
print('the shape of data frame is :',df.shape)
print('the shape of X_train is :',X_train.shape)
print('the shape of X_test is :',X_test.shape)
print('the shape of y_train is :',y_train.shape)
print('the shape of y_test is :',y_test.shape)
# Out:
# the shape of data frame is : (30, 2)
# the shape of X_train is : (21, 1)
# the shape of X_test is : (9, 1)
# the shape of y_train is : (21,)
# the shape of y_test is : (9,)

# %% [markdown]
# **6. Implement the model**

# %%
LR=LinearRegression()
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **7. Make predictions**

# %%
y_predictions=LR.predict(X_test)
y_predictions
# Out:
# array([ 55630.13259001,  62221.33017291,  46214.136043  ,  37739.7391507 ,
#        122483.70807372,  55630.13259001,  44330.9367336 , 102710.11532501,
#         67870.92810111])

# %% [markdown]
# **8. New Dataframe**

# %%
df1=pd.DataFrame(X_test)
df1['Y']=y
df1['Y Prediction']=y_predictions
df1
# Out:
#     YearsExperience       Y   Y Prediction
# 7               3.2   54445   55630.132590
# 10              3.9   63218   62221.330173
# 4               2.2   39891   46214.136043
# 1               1.3   46205   37739.739151
# 28             10.3  122391  122483.708074
# 8               3.2   64445   55630.132590
# 3               2.0   43525   44330.936734
# 23              8.2  113812  102710.115325
# 14              4.5   61111   67870.928101

# %%
ip1=[1]
LR.predict([ip1])
# Out:
# array([34914.9401866])

# %% [markdown]
# **9. Model evaluation**

# %%
R2_score=r2_score(y_test,y_predictions)
MSE=mean_squared_error(y_test,y_predictions)
RMSE=np.sqrt(MSE)

# %%
print(f'R2_score : {R2_score}')
print(f'Mean Square Error : {MSE}')
print(f'Root Mean Square Error : {RMSE}')
# Out:
# R2_score : 0.949721948148016
# Mean Square Error : 40149896.466138825
# Root Mean Square Error : 6336.39459520466

# %%
X_test
# Out:
#     YearsExperience
# 7               3.2
# 10              3.9
# 4               2.2
# 1               1.3
# 28             10.3
# 8               3.2
# 3               2.0
# 23              8.2
# 14              4.5

# %% [markdown]
# **10. Save the Model**

# %%
pickle.dump(LR,open('linear_salary_model.pkl','wb'))
